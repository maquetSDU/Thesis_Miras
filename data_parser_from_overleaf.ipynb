# %%
a = """\item \fullcite{Shynkevich2015} \\
\begin{itemize}
    \item Data source: S\&P 500, LexisNexis, Yahoo Finance
    \item Preprocessing: Bag-Of-Words to feature extraction,  Porter's stemming algorithm is applied to each word to extract stems in order that different forms of the same word are treated equally
    \item Model: Multiple kernel learning (MKL), Support Vector Machines (SVM), kNN 
    \item Metric: Accuracy
    \item Best result: Multiple kernel learning (MKL) wuth 81.63\%
\end{itemize}


\item \fullcite{Dong2020} \\

\begin{itemize}
    \item Data source: Twitter, kibot.com
    \item Main modules of work: Twitter News Crawler, Relevance-Based Tweet Extractor, Sentiment-Based Tweet Feature Extractor, Price Prediction Network
    \item Models: BERT, Autoregressive LSTM
    \item Metric: Root Mean Square Error(RMSE), ROC-AUC
    \item Results: AUC 0.55 when SOTA - 0.52
\end{itemize}



\item \fullcite{Shah2018} \\
\begin{itemize}
    \item Data source: Nifty Pharma Index for sentiment analysis, moneycontrol.com
    \item Model: Auto Regressive Integrated Moving Average (ARIMA), Long short-term memory (LSTM) 
    \item Metric: Accuracy
    \item Result: achieved a directional accuracy of 70.59\% in predicting the
trends in short-term stock price movement
\end{itemize}


\item \fullcite{Cheng2010} \\
\begin{itemize}
    \item Data source: Taiwan Stock Exchange Corporation, news of Money DJ from January 1, 2007 to October 31, 2009
    \item Method: Forecasting the change of intraday stock price
    \item Model: Support Vector Machine (SVM)
    \item Metric: Accuracy
    \item Result: 100\%, Low dataset
\end{itemize}

\item \fullcite{Tang2009} \\
\begin{itemize}
    \item Data source: News articles from news.baidu.coma and stock prices from Shanghai Stock Market during March 2008 to July 2008
    \item Method: Time-series forecasting analysis
    \item Model: News mining and Time series analysis based Forecasting, own new model
    \item Metric: Average absolute difference rate
    \item Result: NTF performs well in forecasting the stock price
\end{itemize}

\item \fullcite{Kaushal2017} \\
\begin{itemize}
    \item Data source: Reuters website, Quandl.com, Google trend index data from Google Trend website
    \item Method: Classification
    \item Model: Naïve Bayes, Logical Regression, Support Vector Machine (SVM)
    \item Metric: Accuracy
    \item Result: Accuracies ranging from 83\% to 89\% for Naive Bayes, 88\% to 92\% for Logical Regression and 84\% to 96\% for SVM classifier
\end{itemize}

\item \fullcite{Yu2017} \\
\begin{itemize}
    \item Data source: Vanke's stock information from June 19, 2008 to June 9, 2012 from Hexun web site, Chinese sentiment dictionary NTUSD
    \item Method: Time-series prediction
    \item Model: BP(Back Propagation) Neural Network Model
    \item Metric: Mean Square Error (MSE) and  Trend Directional Accuracy (TDA)
    \item Result: 0.3818(MSE) and 93.34\%(TDA), which means outstanding performance 
\end{itemize}

\item \fullcite{Yang2018} \\
\begin{itemize}
    \item Data source: News of Reuters and Bloomberg in financial sector from 10/10/2006 to 26/11/2013, S&P500 stock prices
    \item Method: Classification, predicting stock price movement
    \item Model: EB-NN, EB-CNN, GRU-2ATT neural networks
    \item Metric: Matthews Correlation Coefficient (MCC), Accuracy
    \item Result: 0.74\%(Accuracy) and  0.47\%(MCC) for Minnesota Mining and Manufacturing (3M);  0.68\%(Accuracy) and  0.47\%(MCC) for Google; 0.62\%(Accuracy) and 0.21\%(MCC) for Apple.
\end{itemize}

\item \fullcite{Khairi2019} \\
\begin{itemize}
    \item Data source: Stock market EOD data and news from respected websites
    \item Method: Classification
    \item Model: Decision tree J48 model, Support Vector Machine (SVM)
    \item Metric: Accuracy
    \item Result: Accuracy of this model is approximate 91\% with real-time experiments
\end{itemize}

\item \fullcite{Hagenau2012} \\
\begin{itemize}
    \item Data source: German Adhoc messages, DGAP and EuroAdhoc, corporate announcements from Germany and the UK published between 1998 and 2010
    \item Selection Method: Chi²-based feature selection
    \item Method: Classification
    \item Model: Support Vector Machine (SVM)
    \item Metric: Accuracy
    \item Result: average 65.1\%
\end{itemize}

\item \fullcite{Kim2019} \\
\begin{itemize}
    \item Data source: Articles from bigkinds.or.kr, 2016 March 8 to 2018 December 31
    \item Method: Sentimental analysis by building and analyzing a sentimental dictionary with news articles
    \item Model: Convolutional Neural Network (CNN) and Long Short-Term Memory (LSTM)
    \item Metric: Correlation rate between sentiment(positive or negative) and stock price change
    \item Result: Approximately 0.3034 correlation value, which means outstanding result
\end{itemize}

\item \fullcite{Guo2020} \\
\begin{itemize}
    \item Data source: Yahoo Finance data between January 1st, 2015 and August 13th, 2020, Twitter, The New York Times
    \item Method: Time-series stock price prediction
    \item Model: Long Short-Term Memory (LSTM)
    \item Metric: Mean Square Error (MSE) and Mean Absolute Error (MAE)
    \item Result: Indicates that the LSTM model is effective in predicting time series
\end{itemize}

\item \fullcite{Ray2021} \\
\begin{itemize}
    \item Data source: NSE of India data from January 1, 2015 to March 29, 2019, Twitter website
    \item Method: Time-series stock price prediction
    \item Model: Long Short-Term Memory (LSTM), ARIMA-LSTM, BST-LSTM
    \item Metric: Mean Squared Error (MSE) and Mean Absolute Percentage Error (MAPE)
    \item Result: BST-LSTm is the best with 0.004 and 0.0055 on train and test datasets respectively
\end{itemize}

\item \fullcite{Mohan2019} \\
In this research authors used SVM classifier, RNN LSTM and Facebook Prophet to predict stock price  using sentiment analysis techniques. Used OpenNLP to extract sentences from news articles and SentiStrength library with Loughran-McDonald Financial Sentiment dictionary to detect sentiment. As main metric they used Mean Absolute Percentage Error (MAPE). 


\item \fullcite{Gidfalvi2001UsingNA} \\
\begin{itemize}
    \item Data source: The data have been obtained from Lavrenko(KDD-2000: Workshop on Text Mining) contains both prices in 10-minute intervals and news articles with timestamps for 127 stocks for the time period ranging from 1999/11/14 to 2000/02/11 and NASDAQ.
    \item Method: Short-term stock price movements, classification
    \item Model: Naive Bayes
    \item Metric: Beta-value, r-square
    \item Result: Predictive power of the classifier is low
\end{itemize}

\item \fullcite{Mittermayer2004} \\
\begin{itemize}
    \item Data source: Press releases NYSE and NASDAQ-AMEX
    \item Method: Classification
    \item Model: NewsCATS
    \item Metric: Weighted Recall
    \item Result: Authors implemented NewsCATS, which automatically analyzes and categorizes press releases and generates stock trading recommendations. The results indicate that NewsCATS can provide trading strategies that significantly outperform a trader randomly buying and shorting stocks immediately after the publication of press releases. However, the results also reveal that there is still much room for improvement.
\end{itemize}

\item \fullcite{Xie2013} \\
\begin{itemize}
    \item Data source: Reuters from January 2007 through August 2012,  S\&P 500
    \item Method: propose two approaches for the use of semantic frames. The first is a rich vector space based on semantic frames, word forms and DAL affect scores. The second is a tree representation that encodes semantic frame features, and depends on tree kernel measures for support vector machine classification
    \item Model: BOW, sLDA, FWD, SemTreeFWD
    \item Metric: Matthews correlation coefficient (MCC)
    \item Result: The experimental results for our feature representation perform significantly better than BOW on the polarity task, and show promise on the change task. It also facilitates human interpretable analysis to understand the relation between a company’s market value and its business activities. The signals generated by this algorithm could improve the prediction of a financial time series model, such as ADS (Rydberg and Shephard, 2003).
\end{itemize}\

\item \fullcite{Chua2009ASD} \\
\begin{itemize}
    \item Data source: They use the first six months of 2004 HotCopper ASX stock-based discussions.
    \item Method: Sentiment prediction engine that allows for the real-time classification of sentiment on internet stock message boards.
    \item Model: NB Baseline, CNB, CNB IG, NB Binarised, NB Binarised IG.
    \item Metric: Accuracy, Recall, Precision, F-score.
    \item Result: Best performance is seen in the CNB and Bernoulli classifiers. The overall accuracy of both classifiers, at 78.72\% and 78.45\%.
\end{itemize}

\item \fullcite{Devitt2007} \\
\begin{itemize}
    \item Data source:  Gold Standard data set
    \item Method: This paper presents a lexical cohesion based metric of sentiment intensity and polarity in text and an evaluation of this metric relative to human judgments of polarity in financial news.
    \item Model: Cohesion-based Text Representation
    \item Metric: F-score
    \item Result: This paper presents a lexical cohesion based metric of sentiment intensity and polarity in text and an evaluation of this metric relative to human judgments of polarity in financial news.
\end{itemize}

\item \fullcite{Haider2011} \\
\begin{itemize}
    \item Data source: NewsCorp Dataset, ABC news, Reuters, MSNBC, CBC News Online, etc
    \item Method: Valence identification and news classification
    \item Model: Naive Bayes, SVM, Logistic Regression, AdaBoost. 
    \item Metric: Accuracy, Recall, Precision, F-score.
    \item Result: The system gives good result for positive and negative sentiments but satisfactory results for neutral sentiments. An overall accuracy of 79.93\% is obtained.
\end{itemize}

\item \fullcite{Kogan2009} \\
\begin{itemize}
    \item Data source:  SEC(Securities and Exchange Commission)
    \item Method: Make predictions about measurable phenomena in the real world
    \item Model: SVR(Epsilon-Support Vector Regression)
    \item Metric: MSE(Mean Squared Error)
    \item Result: They applied the technique to predicting financial volatility from companies’ 10-K reports, and found text regression model predictions to correlate with true volatility nearly as well as historical volatility, and a combined model to perform even better.
\end{itemize}

\item \fullcite{Deng2018} \\
\begin{itemize}
    \item Data source: Weibo data  
    \item Model: Stock Market Prediction Model Based On Weibo Sentiment
    \item Metric: R-squared
    \item Result: There is a significant long-term equilibrium relationship among the Shanghai Composite Index and Weibo sentiment, P/E ratio and turnover rate. The fluctuations of Weibo sentiment, P/E ratio and turnover rate will significantly affect the Shanghai Composite Index. 
\end{itemize}

\item \fullcite{Huan2020} \\
\begin{itemize}
    \item Data source:  They crawled investors’ comments and companies’ news of the top 15 listed medical companies from the “Oriental Fortune website” generated between January 2010 and November 2019. A total of 530,813 documents were obtained, which include comments and news.
    \item Method: Forecasting stock price
    \item Model: Doc-W-LSTM, ARIMA, LSTM, RNN
    \item Metric: Mean Absolute Error (MAE), Root Mean Square Error (RMSE) and R-squared (R2)
    \item Result: Experimental results show that the proposed method(Doc-W-LSTM) is superior to other baseline methods in MAE, RMSE and R2.
\end{itemize}

\item \fullcite{Bollen2011} \\
\begin{itemize}
    \item Data source: Twitter, Yahoo!
    \item Method: Classification, sentiment predict
    \item Model: Self-organizing Fuzzy Neural Network (SOFNN)
    \item Metric: Mean Average Percentage Error(MAPE), Accuracy
    \item Result: Results show that changes in the public mood state can indeed be tracked from the content of large-scale Twitter feeds by means of rather simple text processing techniques and that such changes respond to a variety of socio-cultural drivers in a highly differentiated manner.
\end{itemize}

\item \fullcite{HAGENAU2013} \\ 
\begin{itemize}
    \item Data source: DGAP, EuroAdhoc
    \item Method: Classification
    \item Model: support vector machine(SVM)
    \item Metric: Accuracy
    \item Result: Research shows that the combination of advanced feature extraction methods and authors feedback-based feature selection boosts classiﬁcation accuracy and allows improved sentiment analytics. Feature selection signiﬁcantly improves classiﬁcation accuracies because authors approach allows reducing the number of less-explanatory features, i.e., noise, and thus, may limit negative effects of over-ﬁtting when applying machine learning approaches to classify text messages.
\end{itemize}

\item \fullcite{Duong2016} \\
\begin{itemize}
    \item Data source: vietstock.vn, hsx.vn, hsn.vn between May 1st, 2014 and April 30th, 2015, VN30 index
    \item Method: Classification, stock price direction 
    \item Model: Support Vector Machine(SVM)
    \item Metric: Accuracy, Precision, Recall
    \item Result: They have proved the correlation between financial news and stock prices in VN30 index. High accuracy(73\%) 
\end{itemize}

\item \fullcite{Gao2010} \\
\begin{itemize}
    \item Data source: Sina Finance
    \item Method: Sentiment classiﬁcation
    \item Model: Weka, Naïve Bayes, KNN and SVM
    \item Metric: Precision, Recall, F-Measure
    \item Result: We(authors) achieved the accuracy of 83\%. According to the experiments, we found that the two key factors that influenced the classification seriously were a good text preprocessing and an appropriate sentiment dictionary. We also found the distinction between different classification methods is not obvious.
\end{itemize}

\item \fullcite{Liu2007} \\

\begin{itemize}
    \item Data source: parsed blogs text by using links or URLs from Blogspace
    \item Method: sales interest increasing prediction
    \item Model: ARSA, S-PLSA
    \item Metric: Mean absolute percentage error(MAPE)
    \item Result: They have explored the predictive power of blogs using movies as a case study, and studied the problem of predicting sales performance using sentiment information mined form blogs. The accuracy and eﬀectiveness of model have been conﬁrmed by the experiments on the movie data set.
\end{itemize}

\item \fullcite{KOHZADI1996} \\

\begin{itemize}
    \item Data source:  USDA (United States Department of Agriculture) Statistical Bulletins.
    \item Method: Time series based stock price forecasting 
    \item Model: ARIMA, Neural Network(NN)
    \item Metric: Mean Square Error(MSE),  Absolute Mean Error(AME), Mean Absolute Percent Error(MAPE)
    \item Result: Results show mean squared errors of 9.478 and 0.199 for the ARIMA live cattle and wheat models, respectively, as compared to the more accurate neural network MSE of 6.845 and 0.087. For the ARIMA models, absolute mean errors were 2.397 the live cattle and 0.190 for the wheat. Mean absolute percentage errors were 4.458 for the live cattle and 5.759 for the wheat. Results showed the neural network forecasts were considerably more accurate than those of the traditional ARIMA models, which were used as a benchmark. 
\end{itemize}

\item \fullcite{Wuthrich1998} \\
\begin{itemize}
    \item Data source: Today’s news
    \item Method: predict stock market prices using text contained in articles from the Web
    \item Model: k-NN
    \item Metric: Accuracy
    \item Result:developed facilities and techniques for exploiting, in particular, textual financial news and analysis results
\end{itemize}

\item \fullcite{Joshi2016} \\

\begin{itemize}
    \item Data source: Apple Inc. open data
    \item Method: Stock price trend prediction
    \item Model:  SVM, Random Forest and Naïve Bayes 
    \item Metric: Accuracy, precision, recall, ROC curve area
    \item Result: Random Forest worked very well with accuracy 88\% to 92\%. Accuracy followed by SVM is 86\% and for Naive Bayes algorithm is 83\%
\end{itemize}

\item \fullcite{Nagar2012} \\
\begin{itemize}
    \item Data source: Google Finance News Feeds
    \item Method: extract stock market sentiment using news
    \item Model: NewsSentiment model
    \item Metric: correlation rate
    \item Result: strong visual correlation between the NewsSentiment score and the stock price
\end{itemize}

\item \fullcite{Lillian2008} \\

\begin{itemize}
    \item Data source:  Rotten Tomatoes, Epinions, Amazon
    \item Method: Classification
    \item Model: Bootstrapping, Logistic regression, SVM
    \item Metric: Accuracy
\end{itemize}


\item \fullcite{Yu2019} \\

\begin{itemize} 
    \item Data source: Yahoo stock US,  stock prices data in U.S
    \item Method: Cycle Embeddings With Attention Mechanism(CEAM) with Deep learning methods
    \item Model:  DA-RNN with CEAM method
    \item Metric: Root mean squared error (RMSE), Mean absolute error (MAE), and Mean absolute percentage error (MAPE)
    \item Result: Solution presented in paper has great performance and outperformed other baseline models
\end{itemize}

\ item \fullcite{Qin2017} \\

\begin{itemize} 
    \item Data source: NASDAQ 100 Stock, SML 2010
    \item Method: Forecasting stock price based on time series data
    \item Model:  DA-RNN model, ARIMA aand others
    \item Metric: Root mean squared error (RMSE), Mean absolute error (MAE), and Mean absolute percentage error (MAPE)
    \item Result: DA-RNN outperformed all other models.
\end{itemize}

\item \fullcite{Ly2020} \\
\begin{itemize} 
    \item Data source: Field-Ritter dataset of company founding dates
    \item Method: Classification
    \item Model: Random Forests, Decision Tree, Naïve Bayes, Logistic Regression
    \item Metric: Accuracy
    \item Result: The logistic regression model performed better that other methods and had accuracy near to 60\%. Authors suspect that they had low accuracy because of volatile nature of IPOs.  
\end{itemize}

\item \fullcite{NGUYEN2015} \\
\begin{itemize} 
    \item Data source: 2 datasets: Historical prices and Message board dataset(Yahoo Message Board)
    \item Method: Stock movement predictions
    \item Model: Support Vector Machine (SVM), Latent Dirichlet Allocation(LDA) and other custom models
    \item Metric: Accuracy
    \item Result: Aspect-based sentiment approach outperformed other solutions with 55\% accuracy in 18 stocks.
\end{itemize}

\item \fullcite{Kanavos2020} \\
\begin{itemize} 
    \item Data source: Stored from different sources(stored in Cassandra database).
    \item Method: Classification
    \item Model: Support Vector Machine (SVM)
    \item Metric: Accuracy
    \item Result: Used 3 types of text preprocessing: unigram, bigrams and tringrams. Tests show that text preprocessed by bigrams method is considiered as the best amoung all solutions.  
\end{itemize}

\item \fullcite{Li2013} \\
\begin{itemize} 
    \item Data source: The Star Online, National News Agency of Malaysia (BERNAMA), The Sun Daily, and New Straits Times (NST) and stock price datasets: Kuala Lumpur Stock Exchange (KLSE)
    \item Method: Classification
    \item Model: Custom algorithms with stemming and without
    \item Metric: Accuracy
    \item Result: The overall accuracy of the stemming lexicon-based approach is 79.1\% which is higher than the accuracy of the non-stemming lexicon-based approach that recorded a 74\% accuracy rate. The use of stemming techniques can improve the accuracy of the model.
\end{itemize}

\item \fullcite{taboada2011} \\
\begin{itemize} 
    \item Data source: Polarity Dataset
    \item Method: Classification(Negative, Positive and Neutral)
    \item Model: Semantic Orientation CALculator (SO-CAL)
    \item Metric: Accuracy
    \item Result: SO-CAL(Full version) correctly predicted 79\% cases.
\end{itemize}

\item \fullcite{turney2002} \\
\begin{itemize} 
    \item Data source: Web pages in English
    \item Method: Classification
    \item Model: Latent Semantic Analysis (LSA), SO-PMI-IR
    \item Metric: Accuracy
    \item Result: SO-PMI-IR can reach the same level of accuracy as Hatzivassiloglou and McKeown’s (1997)(HM) model with 80\%.
\end{itemize}

\item \fullcite{Sharma2019} \\
\begin{itemize} 
    \item Data source: Twitter API to collect tweets, Yahoo Finance data feed to gather stock market data
    \item Method: Classification
    \item Model: Naive Bayes and Multiclass Support Vector Machine(SVM)
    \item Metric: For sentiment prediction: Accuracy, Precision, Recall, F-Measure
    \item Result: Stock prediction for AAPL using Multiclass SVMs accuracy- 65\%. Multiclass SVM outperformed Naive Bayes in sentiment prediction for AAPL stock price trend(Mul. SVM - 78\% and Naive Bayes - 76\%). 
\end{itemize}

\item \fullcite{Mehta2021} \\
\begin{itemize} 
    \item Data source: Tweepy, NASDAQ
    \item Method: Time series price prediction
    \item Model: LSTM, ARIMA, Linear Regression
    \item Metric: RMSE
    \item Result: The ARIMA model is best at forecasting short-term results, while the LSTM model is better for predicting long-term outcomes.
\end{itemize}

\item \fullcite{Mendoza2022} \\
\begin{itemize} 
    \item Data source: NASDAQ and parsed text from Twitter
    \item Method: Time Series predicton
    \item Model: GARCH
    \item Metric: Statistical tests
    \item Result: A simple GARCH cannot explain this fact in typical finance time series.
\end{itemize}

\item \fullcite{YADAV2020} \\
\begin{itemize} 
    \item Data source: NIFTY 50, National Stock Exchange (NSE)
    \item Method: Time Series Stock prediction
    \item Model:  LSTM
    \item Metric: RMSE
    \item Result: The more hidden layers in a LSTM, the more stable it becomes. This is shown by the decreasing standard deviation values and the spread in the box and whisker plot diagram.
\end{itemize}

\item \fullcite{Mankar2018} \\
\begin{itemize} 
    \item Data source: Yahoo API for stock data and Twitter API for tweets
    \item Method: Sentiment analysis and classification
    \item Model: Support Vector Machine (SVM), GPOMS, K-ELM
    \item Metric: Accuracy
    \item Result: K-ELM has best accuracy and is the fastest technique, but requires high computational resources. SVMs accuracy about 64\%, but slow.
\end{itemize}

\item \fullcite{Wang2018} \\
\begin{itemize} 
    \item Data source: Yahoo! Finance, NY Times Archive API
    \item Method: Time series price prediction
    \item Model: Oun custom Neural Network model
    \item Metric: Mean Squared Error (MSE)
    \item Result: The results showed that the model copes well with the task and shows a low level of MSE
\end{itemize}

\item \fullcite{Darapaneni2022} \\
\begin{itemize} 
    \item Data source: Yahoo! Finance, Twitter and Indian news journals
    \item Method: Time series stock price prediction
    \item Model: Linear Regression, KNN, Random forest Regressor, Prophet, ARIMA and LSTM 
    \item Metric: Root Mean Squared Error (RMSE), Mean Absolute Percentage Error (MAPE)
    \item Result: LSTM returning similar level of result as real stock price trends.
\end{itemize}

\item \fullcite{Batra2018} \\
\begin{itemize} 
    \item Data source: tweets from StockTwits and collected stock prices from Yahoo! Finance
    \item Method: Classification for Sentiment prediction and change of stock price 
    \item Model:  Support Vector Machine (SVM), 
    \item Metric: Accuracy, Precision, Recall
    \item Result: Test accuracy for SVM - 76.68\%, 100\% Recall and 69.5\% Precision.
\end{itemize}

\item \fullcite{Sonkiya2021} \\
\begin{itemize} 
    \item Data source: NYSE, NASDAQ and S&P 500 and Yahoo! Finance and news and headlines were collected from Seeking Alpha website
    \item Method: 
    \item Model: ARIMA, LSTM, GRU, GAN, S-GAN
    \item Metric: Root Mean Squared Error (RMSE), Mean Squared Error (MSE)
    \item Result:   Proposed S-GAN uses sentiment analysis output as a latent vector and same hyperparameters as other solutions, but outperformed all of them with 1.827 RMSE result. 
\end{itemize}

\item \fullcite{Ruan2020} \\
\begin{itemize} 
    \item Data source: Pushshift Reddit API and Yahoo! Finance
    \item Method: Time series stock price prediction
    \item Model:  LSTM and SARIMAX (ARIMA family) models
    \item Metric: Custom Accuracy (not for classification)
    \item Result: The LSTM is more efficient than the ARIMA model when it comes to time complexity and tracking stock prices trends.
\end{itemize}

\item \fullcite{Song2020} \\
\begin{itemize} 
    \item Data source: not mentioned in paper, but collected 20 stocks prices and news.
    \item Method: Classification
    \item Model: Support Vector Machine (SVM)
    \item Metric: Sentiment measured by the sentiment variance (SV) and the mean. Accuracy
    \item Result: Experiments have shown that the approach authors proposing can really help predict stock prices based on investor sentiment.
\end{itemize}

\item \fullcite{Pooja2018} \\
\begin{itemize} 
    \item Data source: web sources for different companies (Apple, Google, Microsoft, Amazon).
    \item Method: Stock price trend prediction.
    \item Model: Support Vector Machine (SVM) for sentiment classification and Simple Linear Regression for stock price trend prediction.
    \item Metric: Root Mean Square Error (RMSE), R-Squared value, Accuracy.
    \item Result: The accuracy of the Apple Company is 81.3488\%, Google Company is 98.2878\%, Microsoft Company is 98.2186\% and Amazon Company is 98.2186\%. 
\end{itemize}

\item \fullcite{AlAradi2020} \\
\begin{itemize} 
    \item Data source: Yahoo! Finance, Twitter API
    \item Method: Time series stock pice prediction
    \item Model: Custom Deep Neural Networks (DNN) and Long- Short Memory Neural Network (LSTM)
    \item Metric: Mean Squared Error (MSE)
    \item Result: When it came to prediction accuracy, the LSTM model scored 75.4 test mean squared error and 89.2 validation error compared to 68.1 and 92.1 for the DNN model, respectively.
\end{itemize}

\item \fullcite{Li2017} \\
\begin{itemize} 
    \item Data source: S&P 100 index, Twitter
    \item Method: Time series stock price forecasting
    \item Model: Hidden Markov Model
    \item Metric: Correlation rate 
    \item Result: It has been shown that there is a significant relationship between the stock market volatility and the emotion index.
\end{itemize}

\item \fullcite{Malwana2020} \\
\begin{itemize} 
    \item Data source: Colombo Stock Exchange (CSE), Twitter API.
    \item Method: 
    \item Model:   K Nearest Neighbor (KNN), Decision Tree Model, Support Vector Machine (SVM), Logistic Regression and Multinomial Naïve Bayes.
    \item Metric: Accuracy
    \item Result: With accuracy scores of 72.352941 for Logistic Regression and 71.764706 for Naive Bayes, respectively, they both perform well in all types of testing.
\end{itemize}

\item \fullcite{Kalra2019} \\
\begin{itemize} 
    \item Data source: Collected from various websites.
    \item Method: Classification
    \item Model: K Nearest Neighbor (KNN), Support Vector Machine (SVM), Naive Bayes, and Neural Network.
    \item Metric: Accuracy
    \item Result: The prediction model demonstrates how using the KNN algorithm, numerical sentiment values and variance with open, high, and low value may increase prediction accuracy up to 91.2\%. Additionally, the outcomes demonstrate that variance characteristic has a significant impact on stock price movement.
\end{itemize}

\item \fullcite{Sarode2019} \\
\begin{itemize} 
    \item Data source: NSE(National Stock Exchange), News sources
    \item Method: Time series stock price forecasting
    \item Model: Long- Short Memory Neural Network (LSTM) and Python News Analyser Package.
    \item Metric: no information
    \item Result: The system then generates an analysis report indicating the names of the stocks and their percentage change after integrating the anticipated outcomes with the news analytics summarized results using a variety of parameters.
\end{itemize}

\item \fullcite{Coelho2019} \\
\begin{itemize} 
    \item Data source: StockTwits, Quandl
    \item Method: Classification
    \item Model:  Naive Bayes, Support Vector Machines (SVM), and Neural Networks (MultiLayer Perceptron) 
    \item Metric: Accuracy
    \item Result: The Multi-Layer Perceptron (MLP) classifier gave the highest accuracy.
\end{itemize}

\item \fullcite{Aasi2021} \\
\begin{itemize} 
    \item Data source: Twitter, Google trends
    \item Method: Time series stock price prediction
    \item Model:  Autoregressive Integrated Moving Average (ARIMA), Linear Regression, Artificial Neural Network (ANN), Random Forest (RF), Support Vector Machine (SVM), Long-Short Memory Neural Network (LSTM) and MMLSTM.
    \item Metric: Mean arctangent absolute percentage error (MAAPE), Mean Squared Error (MSE).
    \item Result: It has been demonstrated that forecasting Apple Stock using a proposed MMLSTM model accurately predicts the stock pieces for the upcoming week.
\end{itemize}

\item \fullcite{Alamsyah2018} \\
\begin{itemize} 
    \item Data source:
    \item Method:  Classification
    \item Model: Support Vector Machine (SVM) and Naïve Bayes Classifier (NBC)
    \item Metric: Precision, Recall, Accuracy, F-measure and KAPPA.
    \item Result: As evidenced by 62\% precision, 52.33\% recall, 78.01\% accuracy, 56.75\% f-measure, and 0.1 KAPPA, SVM classifier outperforms Nave Bayes classifier. Authors' proposed ANN-based prediction model has 99.93\% accuracy level in predicting future stock price.
\end{itemize}

\item \fullcite{Sangsavate2019} \\
\begin{itemize} 
    \item Data source: Thai FinTech news, Yahoo! Finance, Twitter
    \item Method: Classification
    \item Model:  Naïve Bayes classifier and support vector machine (SVM)
    \item Metric: Precision, Recall, F-Measure and Accuracy
    \item Result: The results show that the Support Vector Machine (SVM) has a better performance than the Naïve Bayes classifier. 
\end{itemize}

\item \fullcite{Mishev2019} \\
\begin{itemize} 
    \item Data source:  Thompson Reuters News Archive (TRNA), Kaggle (Daily Historical Stock Prices)
    \item Method: Classification
    \item Model:  LSTM Network Model, CNN-LSTM Network Model, ConvLSTM Network Model
    \item Metric: Accuracy
    \item Result: The outcomes demonstrate that the ConvLSTM model performs better than the LSTM and CNN-LSTM models. ConvLSTM also performs better in terms of forecasting both positive class (revenue growth) and negative class (revenue fall) for the companies in the test set, as shown by sensitivity and specificity.
\end{itemize}

\item \fullcite{Jessica2019} \\
\begin{itemize} 
    \item Data source: Twitter, Wall Street Journal, Market Watch, Forbes, Reuters, and CNB. Yahoo! Finance
    \item Method: Classification
    \item Model:  Support Vector Machine (SVM), Random Forest
    \item Metric: Accuracy, Precision, and Recall
    \item Result: When compared to other approaches, MA5 yields the most profit, but traders must trade Facebook stocks every day. The CNBC account is the finest news account among the five official news accounts as a source of sentiment data research on Facebook firms when MA5 is paired with sentiment analysis of tweets.
\end{itemize}

\item \fullcite{LienMinh2018} \\
\begin{itemize} 
    \item Data source: Yahoo! Finance
    \item Method: Classification
    \item Model: GRU, LSTM, Proposed TGRU
    \item Metric: Accuracy, Precision, and Recall
    \item Result: The suggested Two-stream Gated Recurrent Unit (TGRU) outperformed the performance of the prior model, which included GRU and LSTM, with an overall accuracy of 66.32%.
\end{itemize}

\item \fullcite{Roslan2018} \\
\begin{itemize} 
    \item Data source: Twitter, NASDAQ
    \item Method: Time Series stock price prediction
    \item Model: Artificial Neural Network (ANN)
    \item Metric: Mean Squared Error (MSE) 
    \item Result: It is proved that the day trader can use this machine learning technology to precisely mimic the price of the stocks of the company of his or her choice by comparing the projected stock price to the actual stock price, which is extremely great.
\end{itemize}

\item \fullcite{Wu2019} \\
\begin{itemize} 
    \item Data source: Anue websitee (https://www.cnyes.com/)
    \item Method: Time series stock price forecasting
    \item Model: Hierarchical Attention Network (HAN) and modified HAN models
    \item Metric: Mean Absolute Error (MAE), Root Mean Square Error (RMSE), Medium Absolute Error (MDAE)
    \item Result: HKAN model outperformed other HAN family models with MSE 0.78.
\end{itemize}

\item \fullcite{Attanasio2019} \\
\begin{itemize} 
    \item Data source: U.S. S&P 500 index, Yahoo! Finance
    \item Method: Classification
    \item Model:  K-Nearest Neighbor (KNN),  Naive Bayes (MNB),  Random Forest (RFC), Multinomial Naive Bayes (MNB),  MultiLayer Perceptron (MLP)
    \item Metric: Root Mean Square Error (RMSE)
    \item Result: To execute trend reversal detection, news information should be taken into account. Classifiers that have been trained on news data are reliable enough to be successfully included into trend reversal trading systems. Authors were able to outperform (or, in the worst case, be comparable to) the most renowned oscillators used in technical analysis to identify trend reversal by combining news data with historical price series.
\end{itemize}

\item \fullcite{Qiu2019} \\
\begin{itemize} 
    \item Data source: Downloaded from internet
    \item Method: Classification
    \item Model: Candlestick Patterns
    \item Metric: Accuracy
    \item Result: The authors were able to demonstrate that only two of the six candlestick patterns were useful and instructive through unbiased testing using nine US stocks, whereas the other four are not. Investors should therefore be clear on their overall correctness and the projected revenue before directly applying the candlestick analysis approach to current stock market data.
\end{itemize}

\item \fullcite{Kesavan2020} \\
\begin{itemize} 
    \item Data source:  National Stock Exchange (NSE) and the Bombay Stock Exchange (BSE)
    \item Method: Time series stock price forecasting
    \item Model: Long-Short Memory Neural Network (LSTM)
    \item Metric: Custom Accuracy and Precision
    \item Result: Based on the aforementioned criteria, the suggested method's percentage error is 3.05 percent, and as a result, the proposed system's accuracy is approximately 96.95 percent, which is higher than the work that has already been done.
\end{itemize}

\item \fullcite{Thu2021} \\
\begin{itemize} 
    \item Data source: US and Vietnam stock market
    \item Method: Time series stock price prediction
    \item Model: Neighborhood LSTM model, Linear regression, Random forest regression, Convolutional neural network 
    \item Metric: Mean Absolute Error (MAE),  Root mean square error (RMSE) and Symmetric mean absolute percentage error (SMAPE)
    \item Result: It is clear that the LSTM-kNN network almost perfectly analyzes and captures trends while providing precise forecasts.
\end{itemize}

\item \fullcite{Nishitha2020} \\
\begin{itemize} 
    \item Data source: National Stock Exchange
    \item Method: Classification
    \item Model:  Convolution Neural Network (CNN), LSTM 
    \item Metric: Accuracy
    \item Result: Accuracy is 86.6\%
\end{itemize}

\item \fullcite{Kumar2020} \\
\begin{itemize} 
    \item Data source: no information
    \item Method: Classification
    \item Model: Recurrent Neural Network - Long-Short Memory Neural Network (RNN-LSTM) model
    \item Metric: Accuracy
    \item Result: Important technical indicators reveal a stock's volatility, momentum, and direction as well as if it has been oversold or overbought. Any long- or short-term pattern present in the feature vectors can be automatically recognized by the RNN-LSTM model. In comparison to any other pair of feature vector types, the accuracy has enhanced when the key indicators, news sentiment, and numerical data are included as feature vectors.
\end{itemize}

\item \fullcite{Peng2019} \\
\begin{itemize} 
    \item Data source: Sina.com and various APIs for collecting news text
    \item Method: Statistical analysis of stock price trend based on sentiment classification 
    \item Model: Statistical approaches
    \item Metric: statistical indicators
    \item Result: The stock's most recent overall trend can be fitted using the similarity of the 5-day average and 30-day average trends. However, because the stock price trend is influenced by a variety of stock market conditions, writers discover that the 5-day and 30-day averages are considerably different at some instances.
\end{itemize}

\item \fullcite{Merello2018} \\
\begin{itemize} 
    \item Data source: NASDAQ, Twitter
    \item Method: Classification
    \item Model: ARMA (Auto Regressive Moving Average),  Rule classifier (RC), SNW mode, ANW model
    \item Metric: Matthews correlation coefficient (MCC), Accuracy
    \item Result: Both ANW and SNW's forecasts appear to be highly associated with historical price changes. The model that performs the best at predicting the end of the current trend is ANW (62.8\% accuracy, 0.18 MCC). In reality, ANW is able to predict better than other models, and even for predictions of movements far into the future, it has a considerable MCC.
\end{itemize}

\item \fullcite{Reddy2020} \\
\begin{itemize} 
    \item Data source: Twitter API, S&P5 00 index, NASDAQ
    \item Method: Classification
    \item Model: Logistic Regression, Decision Tree, SVM and KNN, Random
forest algorithm
    \item Metric: Accuracy
    \item Result: The correlation between price and sentiment is discovered after the model has been trained, and this value is utilized to make future predictions. The prediction process uses a machine learning model. Based on these values, a machine learning model is developed, after which a forecast is made.
\end{itemize}

\item \fullcite{Kumar2021} \\
\begin{itemize} 
    \item Data source: NASDAQ, Stock Exchange of Thailand (SET), S&P 500 , 
    \item Method: Time series stock price prediction
    \item Model: Moving Average Method, Liner Regression Method, K–Nearest Neighbours (KNN) model, Auto Arima, Prophet, Long Short Term Memory(LSTM)  
    \item Metric: Root Mean Square(RMS), R-Squared (R2) Score, Mean Absolute Error(MAE)
    \item Result: LSTM model outperformed other solutions with results: RMS - 9.42, R2 - 0.81 and MAE - 8.6.
\end{itemize}

\item \fullcite{Lauren2019} \\
\begin{itemize} 
    \item Data source: Financial Modeling Prep API, Alpha Advantage API
    \item Method: Time Series stock price prediction and classification of sentiment
    \item Model: Long Short-Term Memory (LSTM), SVM
    \item Metric: Root mean square error (RMSE), Accuracy
    \item Result: This study displays and exemplifies the usage of the Rasa framework to develop a conversational user interface for stock analysis. Stock price retrieval, stock sentiment, the most recent financial news, stock forecast, and historical stock price plots are among the primary Stock Analysis CUI elements that have been introduced.
\end{itemize}

\item \fullcite{Jariwala2020} \\
\begin{itemize} 
    \item Data source: moneycontrol.com, news headline of Mahindra and Mahindra Ltd.
    \item Method: Classification
    \item Model: K-means Clustering, Naïve Bayes, Support Vector Machine (SVM) 
    \item Metric: Accuracy
    \item Result: Both SVM and NB have accuracy levels that are practically identical(and both outperformed K-means), with NB having slightly greater accuracy than SVM. SVM provided an accuracy of 66.23\% while NB provided an accuracy of 66.42\% for Mahindra & Mahindra Ltd., and 82.47\% and 82.87\%, respectively, for Kotak Mahindra Bank Ltd.
\end{itemize}

\item \fullcite{Xu2020} \\
\begin{itemize} 
    \item Data source: Wind economic database, Crawl financial news and stock data
    \item Method: Classification, stock price direction
    \item Model: CCN, Bi-LSTM
    \item Metric: Accuracy
    \item Result: Comparing the suggested model to the other 3 techniques, it has the highest prediction accuracy performance, predicting stock price changes with an accuracy of 85.71 percent.
\end{itemize}

\item \fullcite{Qi2021} \\
\begin{itemize} 
    \item Data source: Twitter
    \item Method: Time series stock price prediction
    \item Model: LSTM
    \item Metric: Mean Square Error(MSE)
    \item Result: This outcome may be the result of the general public's terror and sometimes unreasonable sentiment amid extreme conditions like COVID-19. Public opinion in this case might not be useful. As a result, using mood data to forecast stock movement may be deceptive and have a limited positive impact.
\end{itemize}

\item \fullcite{Chao2019} \\
\begin{itemize} 
    \item Data source: Taiwan Stock Price Index 
    \item Method: Time series stock price prediction
    \item Model: Support vector machine (SVM), K-Means, Word2vec (for NLP) and neural network
    \item Metric: no inforamtion
    \item Result: The suggested system can assist in securing the investment decision with keyword extraction, analysis, and correlation calculations with stock prices. The idea is that understanding the background of the issues and the impact of opinion leaders on the stock market may be gained by analyzing the opinions and feelings expressed on social media.
\end{itemize}

\item \fullcite{Yıldırım2018} \\
\begin{itemize} 
    \item Data source: Jones Newswires Text Feed
    \item Method: Classification
    \item Model: Logistic Regression (LR), Support Vector Machine (SVM), k-Nearest Neighbours (kNN) and multinomial Na¨ıve Bayes (mNB)
    \item Metric: Success rate, precision, recall, F1-measure and area under curve (AUC)
    \item Result:  Logistic Regression (LR) model outperforms other classifiers in terms of all metrics.
metrics
\end{itemize}

\item \fullcite{Cakra2015} \\
\begin{itemize} 
    \item Data source: Yahoo! Finance and Twitter
    \item Method: Time series Stock price forecasting 
    \item Model: Support Vector Machine (SVM), Naïve Bayes, Decision Tree, Random Forest, Neural Network - for sentiment classification and Linear regression - for time series stock price prediction 
    \item Metric: Accuracy and R2
    \item Result: The outcome reveals that the prediction model that used the price feature on five previous days produced the greatest R2 value, which was 0.9989. It is followed by a prediction model with a hybrid feature on the five days prior, which has a 0.9983 accuracy. All developed models generated R2 values that were close to 1.
\end{itemize}

\item \fullcite{Suman2017} \\
\begin{itemize} 
    \item Data source: StockTwits
    \item Method: Classification
    \item Model: Naive Bayes Classifier
    \item Metric: Accuracy
    \item Result: It is inevitable that the Apple Inc. stock market will reflect the popularity of posts on social media. Our research revealed that a social media post may have some bearing on Apple Inc. stock price fluctuations. However, we can only conclude that social media is mostly successful at anticipating stock market fluctuations when posts behave negatively and the stock as a whole exhibits bearish behavior. When the stock market is acting bullishly, it does not operate properly. Social media does not have much of an impact on that behavior.
\end{itemize}

\item \fullcite{Sun2017} \\
\begin{itemize} 
    \item Data source: Weibo, Circle, Snowball and Stock Bar. Shanghai Stock Exchange and Shenzhen Stock Exchange
    \item Method: Classification
    \item Model: SVM, NBSVM model, LSTM, Linear Regression, Ensemble
    \item Metric: Accuracy
    \item Result: The ensemble method achieves the maximum accuracy as expected, and the authors note that the performance is relatively consistent across all the models. The classification accuracy for dataset, with an average accuracy of 0.646, is somewhat better than the state-of-the-art result for brief postings in Twitter, despite the datasets not being directly comparable.
\end{itemize}

\item \fullcite{Zhang2015} \\
\begin{itemize} 
    \item Data source: Twitter, S&P 500
    \item Method: Classification
    \item Model: ECM(energy cascading model (ECM)), SENT(sentiment based), ANN, CORR(correlation)
    \item Metric: Precision, Recall, F-measure, Accuracy
    \item Result: Results demonstrate the effectiveness of the suggested ECM in predicting intermediate directional stock price movements, with an average accuracy of 67.7 percent (67.4 percent) for upward (downward) stock price movements. In fact, the ECM surpasses the best baseline model in terms of F-measure by 11.7 percent when predicting upward stock price movement. Business managers and financial analysts can use the proposed model to more accurately analyze and forecast the performance of targeted enterprises from automatically mined business networks as a result of our research. They can proactively implement the necessary tactics to streamline those companies' processes.
\end{itemize}

\item \fullcite{Tiwari2017} \\
\begin{itemize} 
    \item Data source: Nifty 50, Twitter
    \item Method: Time series stock price prediction
    \item Model: Holt-winters filtering, Neural Networks, ARIMA model, TSLM (Time Series Modelling), The Seasonal Trend Loess model (STL), Support Vector Machine (SVM), Multi-Layer Perceptron Model
    \item Metric: ME, RMSE, MAE, MPE, MAPE, ACF1
    \item Result: Feed forward neural network is the best technique for predicting the opening price of a stock. The authors also noted that alternative strategies for various stocks can yield superior results, and this is also true for other sorts of prices (Open, low, high, and low).
\end{itemize}

\item \fullcite{Yin2016} \\
\begin{itemize} 
    \item Data source:  Sina Financial Network Stock Forum and collected reviews published by users on the Internet
    \item Method: Statistical 
    \item Model: Linear Regression, custom Model 1, 2 and 3
    \item Metric: Coefficient, T
    \item Result: Different factors, such as the impact of different investor sentiment indices on the stock price, are responsible for the change in stock price. Model 3 had the strongest predictive ability when compared specifically, reaching 97.9\%. The accuracy of stock price prediction increases as more elements that influence stock prices are discovered.
\end{itemize}

\item \fullcite{JiahongLi2017} \\
\begin{itemize} 
    \item Data source: CSI300 index
    \item Method: Classification
    \item Model: LSTM+SVm
    \item Metric: Precision, Recall, F-measure, Accuracy 
    \item Result: The capacity of the latter to considerably increase the accuracy of other models to predict CSI300 open price was proved using a Long Short-Term Memory model that was trained using historical values of the CSI300 index and the authors' investor sentiment time series. Given the improvement in performance for the LSTM model with only four layers and a maximum of thirty nodes, we anticipate finding comparable or even greater improvements for more complex market models that may in fact incorporate additional information gleaned from news sources and a variety of pertinent economic indicators.
\end{itemize}

\item \fullcite{Nivetha2017} \\
\begin{itemize} 
    \item Data source: Twitter, The Economic Times and Yahoo! Finance
    \item Method: Classification
    \item Model: Multiple Linear Regression, Support Vector Machine, Artificial Neural Network
    \item Metric: Accuracy
    \item Result: The less developed Multiple Linear Regression algorithm assesses the correlation between stock price and volume. The outcome clearly shows that the deep learning algorithm outperforms the MLR and SVM. The hidden layer neuron learns with each prediction in the deep learning algorithm. As a result, the output layer neuron generates the best results. The best prediction algorithm is an artificial neural network.
\end{itemize}

\item \fullcite{Wang2016} \\
\begin{itemize} 
    \item Data source: Yahoo API and Google API, Sina Weibo, Tong Hua Shun Network and Dong Fang Cai Fu network
    \item Method: Classification
    \item Model: Support Vector Machine (SVM)
    \item Metric: Accuracy
    \item Result: The segment value of each stock's emotion vector was calculated, and the authors discovered that it is extremely sensitive to changes in stock price. Additionally, we found that the SVM model with segment index has higher prediction accuracy than the SVM model without combined segment index through testing our social media mining algorithm.
\end{itemize}

\item \fullcite{Day2016} \\
\begin{itemize} 
    \item Data source: NowNews, AppleDaily, Liberty Times Net (LTN), MoneyDJ Finance
    \item Method: Time series stock price prediction
    \item Model: Custom Neural Network model
    \item Metric: difference between models ROI
    \item Result: MoneyDJ achieved a ROI value of 22.43\% in the prediction model for the situation in the following 60 days, which is much higher than the ROI values obtained by the other news sources' prediction models.
\end{itemize}

\item \fullcite{Coyne2017} \\
\begin{itemize} 
    \item Data source: StockTwits, Quandl
    \item Method: Classification 
    \item Model: Linear Regression, Sentiment based model, Smart User Classification
    \item Metric: Accuracy
    \item Result: Model three(best model) is significant not just for its remarkable accuracy, but also because it demonstrates that sentiment has uses beyond general guessing. If intelligent users can be found, perhaps sentiment can locate intelligent businesses, discussion topics, and followers as well. Social media and the financial market are undoubtedly related, and mood is a powerful predictor.
\end{itemize}

\item \fullcite{GuiyingWei2015} \\
\begin{itemize} 
    \item Data source: Micro-blogs, Shanghai stock composite index, Securities Times Network
    \item Method: Classification
    \item Model:  SVM (Support Vector Machine)
    \item Metric: Accuracy
    \item Result: Only technical indicators have a low accuracy rate since the stock's historical price cannot accurately reflect the variation brought on by policy and unforeseen events. Combining public opinion analysis and prediction accuracy increases the rate of prediction marginally, but when taking into account each blog's level of influence, the accuracy rate increases significantly as the effect of microblogs that attract a lot of attention is increased.
\end{itemize}

\item \fullcite{Alostad2015} \\
\begin{itemize} 
    \item Data source: NASDAQ, Twitter
    \item Method: Classification
    \item Model: Support Vector Machine (SVM), Sparse Logistic Regression
    \item Metric: Accuracy
    \item Result:  Logistic Regression classifier with 1-gram keyword features leads to the best overall directional prediction accuracy
\end{itemize}

\item \fullcite{Pagolu2016} \\
\begin{itemize} 
    \item Data source: Twitter API, Yahoo! Finance
    \item Method: Classification
    \item Model: LibSVM, Logistic Regression, SMO
    \item Metric: Accuracy, Precision, Recall, F-Measure
    \item Result: When utilizing the logistic regression approach to train the classifier, the results reveal an accuracy value of 69.01\%, and the accuracy rate changed depending on the training set. 90 percent of the data were used to train the LibSVM model, which produced a result of 71.82\%. These findings provide investors with a sizable advantage and demonstrate a strong link between stock market movements and popular mood as reflected on Twitter.
\end{itemize}

\item \fullcite{Devi2015} \\
\begin{itemize} 
    \item Data source: Yahoo! Finance 
    \item Method: Time series stock price prediction
    \item Model: SVM, Proposed model(CS-SVM), ANN
    \item Metric: RMSE, MAPE, Error Rate
    \item Result: The acquired experimental findings show that the accuracy rate of the CS-SVM approach can be higher than that of the standard SVM method. The suggested experimental findings show that, when compared to ANN and SVM, CS-SVM offers superior accuracy with lower MSE and MAPE.
\end{itemize}"""

# %%
b = a.split("\item")

# %%
arr = []
for i in b:
    if "Model" in i:
        for j in i.split(":")[1].split(","):
            j = j.replace("\n","")
            arr.append(j.strip())

# %%
from collections import Counter

# %%
Counter(list(arr))
# Out:
# Counter({'Multiple kernel learning (MKL)': 1,
#          'Support Vector Machines (SVM)': 2,
#          'kNN': 1,
#          'BERT': 1,
#          'Autoregressive LSTM': 1,
#          'Auto Regressive Integrated Moving Average (ARIMA)': 1,
#          'Long short-term memory (LSTM)': 1,
#          'Support Vector Machine (SVM)': 19,
#          'News mining and Time series analysis based Forecasting': 1,
#          'own new model': 1,
#          'Naïve Bayes': 5,
#          'Logical Regression': 1,
#          'BP(Back Propagation) Neural Network Model': 1,
#          'EB-NN': 1,
#          'EB-CNN': 1,
#          'GRU-2ATT neural networks': 1,
#          'Decision tree J48 model': 1,
#          'Convolutional Neural Network (CNN) and Long Short-Term Memory (LSTM)': 1,
#          'Long Short-Term Memory (LSTM)': 3,
#          'ARIMA-LSTM': 1,
#          'BST-LSTM': 1,
#          'Naive Bayes': 4,
#          'NewsCATS': 1,
#          'BOW': 1,
#          'sLDA': 1,
#          'FWD': 1,
# ...
